# %% [markdown]
# ---
# toc: True
# comments: True
# layout: post
# title: Final Individual Review
# description: None
# type: hacks
# courses: {'compsci': {'Week': 7}}
# ---

# %% [markdown]
# My main contributions were the guess_game.html, script.js, aim_trainer.js, aim_trainer.html, login.html, and signup.html, with a bit of editing and tinkering within the about.html and game.html. I also created the gemfile and makefile even though we never used them.

# %% [markdown]
# Honestly, I was completely lost this entire first trimester until it came to the passion project where I gained the majority of my understanding of coding and learned how to code a majority of front end (absolutely none of backend I'm kinda dead on that).I've gained a decent understanding of html and javascript, kinda need to understand php better. I plan to gain a better understanding of backend so I can utilize both simultaneously without having to rely on backend being able to keep pace.
#
# We used pseudo code to understand how exactly we were going to create our project and individual games, we created layouts for the style of the game.html so we could understand how people could access the game and used pseudo code
#
# Ny main contribution came when using javascript and connecting it to the html to make the code easier to visually understand and allowed for a much nicer and cleaner ropository consisting of different files that all contribute to a single project or game in most of ny cases.
#
# I had multiple key github commits which consisted of adding games such as the aim_trainer and the guess_game which all added to the actual content of the website. Not only that, but I had also commited and created different pages on the site, such as, the login and the signup pages which allowed for our connection to the backend, giving us the qualification to N@TM (not entirely, but it was required)
#
# None of my code that I had created wasn't used towards the website because I focused strictly on the actual aspects of the website that needed to be added or fixed (bug fixing and content creation)
#
# My code that I had used as learning material over the trimester is within my repository but not my blog (tragic), (I also accidentally deleted my repository, so... kinda sucks) My work is all within each seperate file. My groups team teaching lesson also consisted of multiple examples and prompts that were created by my own efforts

# %%
#This code utilizes pandas which is a way for you as a user, to create data tables that are much more organized

#imports pandas so it's able to be used
import pandas as pd

#data is created and will be sorted from left to right into top to bottom
data = {'Name': ['Matthew', 'Lindsey', 'Josh', 'Ethan'],
        'Grade': [97, 92, 90, 80]}

#defines a variable and utilizes pandas by using a DataFrame for the data
df = pd.DataFrame(data)

#increase the side count by one
df.index += 1

print(df)

# %%
import pandas as pd
import numpy as np

# Sample data
data = {
    'Grade': ['A', 'B', 'A', 'C', 'B', 'C', 'A', 'B', 'A'],
    'Percent': [94, 82, 91, 76, 89, 79, 92, 87, 99]
}

# Create a Pandas DataFrame
df = pd.DataFrame(data)

# Calculate the mean of each Grade using NumPy
means = df.groupby('Grade')['Percent'].mean().reset_index()

# Organize the results into a new data table
result = pd.DataFrame({'Grade': ['A', 'B', 'C'], 'Mean Grade': means['Percent']})

# Display the result
print(result)

# %% [markdown]
# All of the code that I contributed to the main passion project is below and is completely functioning (within the actual repository)
#
# College Board Notes that I took (honestly not that many, I was kinda zoned out if you look at the 45 minutes taken to answer one question cause I was sidetracked) were very short and brief, I understood pseudo code better because it's just another way to outline how code should work, sorta like agile methodology which is kinda basic yet difficult if you aren't able to properly grasp the entire concept. Not only that but I was also confused about how the internet works (how tf) and the basic work questions (cause i'm dumb).
#
#
# A reflection on the past trimester would probably consist of me being completely lost within the setup of vscode and our own repositories, to being lost within code, to gaining an understanding of python, then not using it at all during the passion project, the lastly completely learning how to code in html and a bit in javascript and even less in php to fix errors and create different games. Honestly, I don't know how I made it all the way here, but I would say that just being able to gain an understanding of some code on it;s own is an accmplishment and that I shouldn't be discouraged to learn other types of code. php is probably my weakpoint right now along with requests and api's (wtf is backend). I will say however, that learning form the team teaching has helped me learn as a person how to work with other people and how to teach and talk infront of a group.

# %%
<!DOCTYPE html>
<html>
<head>
    <title>Asian.inc - Login</title>
    <link rel="stylesheet" href="https://joshthinh.github.io/Asian-United-Frontend/style.css"/>
    <style>
        body {
            text-align: center;
            background-image: url("https://joshthinh.github.io/Asian-United-Frontend/images/background.png"); /* Add the path to your background image */
            background-size: cover;
        }
        .login-container {
            width: 300px;
            margin: 0 auto;
            padding: 20px;
            border: 1px solid #cccccc00;
            background-color: rgba(255, 255, 255, 0); /* Adjust the alpha value (0.0 to 1.0) for transparency */
            margin-top: 50px;
        }
        .login-container label {
            color: white; /* Set the text color to white */
        }
        .login-container input[type="text"],
        .login-container input[type="password"] {
            color: black; /* Set the text color to black */
        }
        .login-container h1 {
            color: #ffffff; /* Set the text color of "Login" to a different color */
        }
        .login-guest-button {
            text-align: center;
            position: absolute;
            bottom: 50px;
            right: 0;
            margin: 20px;
        }
        .dont-have-account-button {
            text-align: center;
            position: absolute;
            bottom: 10px; /* Adjust the vertical position */
            right: 0;
            margin: 20px;
        }
    </style>
</head>
<body>
    <!-- Content for Login Page -->
    <div class="login-container">
        <h1>Login</h1>
        <!--<form method="post" action="process_login.php"> -->
            <form id="loginForm">
                <label for="username">Username:</label>
                <input type="text" id="username" name="username" required><br>
        
                <label for="password">Password:</label>
                <input type="password" id="password" name="password" required><br>
        
                <button type="button" onclick="authenticateUser()">Login</button>
            </form>
        
            <div id="output"></div>
        
            <script src="https://joshthinh.github.io/Asian-United-Frontend/passscript.js"></script>
        </form>
    </div>
    <button class="login-guest-button"><a href="game.html">Login as Guest</a></button>
    <button class="dont-have-account-button"><a href="signup.html">Don't Have an Account?</a></button>
    <!-- Include any footer content if needed -->
</body>
</html>
<script>
</script>

# %%
const canvas = document.getElementById("game-canvas");
const ctx = canvas.getContext("2d");
const guessX = document.getElementById("guessX");
const guessY = document.getElementById("guessY");
const moveButton = document.getElementById("moveButton");
const resetButton = document.getElementById("resetButton");
const message = document.getElementById("message");

const gridSize = 20;
const gridRange = 20;
const diamondHalfSize = 1;
const hitZoneSize = 5;

let centerX = canvas.width / 2;
let centerY = canvas.height / 2;

let targetX = centerX;
let targetY = centerY;

let dotX = centerX;
let dotY = centerY;

let dotVisible = false;
let dotBlue = false;

let score = 0; // Initialize the score

const scoreboard = document.createElement("div");
scoreboard.style.position = "absolute";
scoreboard.style.right = "10px";
scoreboard.style.top = "10px";
scoreboard.style.backgroundColor = "darkgray";
scoreboard.style.color = "white";
scoreboard.style.padding = "10px";
scoreboard.style.borderRadius = "5px";
scoreboard.style.fontSize = "24px";
scoreboard.textContent = "Score: 0";

document.body.appendChild(scoreboard);

function updateScoreboard() {
    scoreboard.textContent = `Score: ${score}`;
}

function randomizeTargetPosition() {
    targetX = Math.floor(Math.random() * (canvas.width / gridSize)) * gridSize;
    targetY = Math.floor(Math.random() * (canvas.height / gridSize)) * gridSize;
}

function clearCanvas() {
    ctx.clearRect(0, 0, canvas.width, canvas.height);
}

function drawGrid() {
    ctx.strokeStyle = "#ccc"; 
    ctx.lineWidth = 1;

    // Draw vertical grid lines
    for (let x = 0; x <= canvas.width; x += gridSize) {
        ctx.beginPath();
        ctx.moveTo(x, 0);
        ctx.lineTo(x, canvas.height);
        ctx.stroke();
    }

    // Draw horizontal grid lines
    for (let y = 0; y <= canvas.height; y += gridSize) {
        ctx.beginPath();
        ctx.moveTo(0, y);
        ctx.lineTo(canvas.width, y);
        ctx.stroke();
    }
}

function drawTarget() {
    ctx.beginPath();
    ctx.arc(targetX, targetY, 10, 0, Math.PI * 2);
    ctx.fillStyle = dotBlue ? "blue" : "transparent"; // Set the dot color to transparent
    ctx.fill();
    ctx.closePath();
}

function drawPixelatedBoxWithCorners(x, y, size) {
    const halfSize = Math.floor(size / 2);

    for (let dx = -halfSize; dx <= halfSize; dx++) {
        for (let dy = -halfSize; dy <= halfSize; dy++) {
            if (Math.abs(dx) + Math.abs(dy) < halfSize) {
                ctx.fillStyle = "red";
                ctx.fillRect(x + dx * gridSize, y + dy * gridSize, gridSize, gridSize);
            }
        }
    }
}

function moveTarget() {
    const moveX = parseInt(guessX.value) || 0;
    const moveY = parseInt(guessY.value) || 0;

    // Update the hit zone position based on user input
    dotX += moveX * gridSize;
    dotY -= moveY * gridSize;

    dotBlue = true; // Turn the dot blue
    dotVisible = true; // Show the dot
    clearCanvas();
    drawGrid();
    drawPixelatedBoxWithCorners(dotX, dotY, hitZoneSize); // Draw the custom hit zone
    drawTarget();
}

// ... (Previous code)

function checkWin() {
    const distanceX = Math.abs(targetX - dotX);
    const distanceY = Math.abs(targetY - dotY);

    if (distanceX <= diamondHalfSize * gridSize && distanceY <= diamondHalfSize * gridSize) {
        message.style.color = "white"; // Set text color to white
        message.textContent = "Congratulations! You hit the target.";
    } else {
        message.style.color = "white"; // Set text color to white
        message.textContent = "Missed. The target is outside the hit zone.";
    }

    disableInputAndButton();
}

// ... (Rest of the code)


function disableInputAndButton() {
    guessX.disabled = true;
    guessY.disabled = true;
    moveButton.disabled = true;
}

function enableInputAndButton() {
    guessX.disabled = false;
    guessY.disabled = false;
    moveButton.disabled = false;
}

function restartGame() {
    randomizeTargetPosition();
    dotX = centerX;
    dotY = centerY;
    dotVisible = false; // Hide the dot
    dotBlue = false; // Reset the dot color
    clearCanvas();
    drawGrid();
    drawTarget();
    enableInputAndButton();
    message.textContent = "";
    clearCanvas();
    drawGrid();
    drawPixelatedBoxWithCorners(dotX, dotY, hitZoneSize);
}

randomizeTargetPosition();
clearCanvas();
drawGrid();
drawTarget();
updateScoreboard();

moveButton.addEventListener("click", () => {
    moveTarget();
    checkWin();
});

resetButton.addEventListener("click", () => {
    restartGame();
});

# %%
<!DOCTYPE html>
<html>
<head>
    <title>Asian.inc</title>
    <link rel="stylesheet" href="https://joshthinh.github.io/Asian-United-Frontend/style.css" />
    <script src="https://joshthinh.github.io/Asian-United-Frontend/button.js"></script>
</head>
<body>
    <header class="second-header">
        <button onclick="game()">Games</button>
        <button onclick="about()">About</button>
        <button onclick="home()">Home</button>
        <hr>
    </header>
    <div class="game-container">
        <canvas id="game-canvas" width="400" height="400"></canvas>
        <div id="input-container">
            <input type="number" id="guessX" placeholder="Move X (-20 to 20)">
            <input type="number" id="guessY" placeholder="Move Y (-20 to 20)">
            <button id="moveButton">Move</button>
            <button id="resetButton">Restart</button>
        </div>
        <div id="message" style="color: white;"></div> <!-- Set text color to white -->
    </div>
    <script src="https://joshthinh.github.io/Asian-United-Frontend/script.js"></script>
    <div id="scoreboard" style="color: white;"></div> <!-- Set text color to white -->
</body>
</html>

# %%
document.addEventListener("DOMContentLoaded", function () {
    startGame();
});

function startGame() {
    createBoxes();
}

function applyColor() {
    var colorSelect = document.getElementById("color-select");
    var selectedColor = colorSelect.value;
    var gameArea = document.getElementById("game-area");
    gameArea.style.backgroundColor = selectedColor;
}

function createBoxes() {
    var gameArea = document.getElementById("game-area");

    for (var i = 1; i <= 3; i++) {
        var box = document.createElement("div");
        box.className = "box";
        box.textContent = i;
        box.addEventListener("click", function (event) {
            boxClicked(event.target);
        });

        gameArea.appendChild(box);
    }
}

function boxClicked(box) {
    // Handle box click logic here
    // 'box' is the clicked box element
}

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>Aim Trainer</title>
    <link rel="stylesheet" href="https://joshthinh.github.io/Asian-United-Frontend/style.css" />
    <script src="https://joshthinh.github.io/Asian-United-Frontend/button.js"></script>
</head>
<body>
    <header class="second-header">
        <button onclick="game()">Games</button>
        <button onclick="about()">About</button>
        <button onclick="home()">Home</button>
        <hr>
    <style>
        /* Add some basic styling for the boxes */
        .box {
            width: 100px;
            height: 100px;
            background-color: red;
            position: absolute;
            cursor: pointer;
        }

        .score {
            position: absolute;
            top: 10px;
            right: 10px;
            color: white; /* Set the text color to white */
        }

        #color-picker {
            position: absolute;
            top: 100px;
            left: 10px;
        }

        h1 {
            color: white; /* Set the text color to white */
        }
    </style>
</head>
<body>
    <h1>Aim Trainer</h1>
    <div id="game-area">
        <!-- Create as many boxes as needed -->
        <div class="box" id="box1"></div>
        <div class="box" id="box2"></div>
        <div class="box" id="box3"></div>
    </div>
    <input type="color" id="color-picker" value="#FF0000">
    <div id="score" class="score">Score: 0</div>
</body>
<script>
    // ... (rest of the JavaScript code remains the same)
</script>
<script>

    const gameArea = document.getElementById("game-area");
    const boxes = document.querySelectorAll(".box");
    const scoreDisplay = document.getElementById("score");
    const colorPicker = document.getElementById("color-picker");

    let score = 0;

    // Function to generate a random position within the screen
    function getRandomPosition() {
        const maxX = window.innerWidth - 100; // Adjust based on box width
        const maxY = window.innerHeight - 100; // Adjust based on box height

        const randomX = Math.floor(Math.random() * maxX);
        const randomY = Math.floor(Math.random() * maxY);

        return { x: randomX, y: randomY };
    }

    // Function to move the clicked box to a random position
    function moveBox(box) {
        const newPosition = getRandomPosition();
        box.style.left = newPosition.x + "px";
        box.style.top = newPosition.y + "px";
        score++;
        scoreDisplay.textContent = "Score: " + score;
    }

    // Event listener to move a box when clicked
    boxes.forEach((box) => {
        box.addEventListener("click", () => {
            moveBox(box);
        });
    });

    // Event listener to change box color when color is picked
    colorPicker.addEventListener("input", (event) => {
        const color = event.target.value;
        boxes.forEach((box) => {
            box.style.backgroundColor = color;
        });
    });

    // Automatically position the boxes when the page loads
    boxes.forEach((box) => {
        const initialPosition = getRandomPosition();
        box.style.left = initialPosition.x + "px";
        box.style.top = initialPosition.y + "px";
    });
</script>
</html>

<script src="/Asian-United-Frontend/script.js"></script>
</html>

# %%
<!DOCTYPE html>
<html>
<head>
    <title>Asian.inc - Login</title>
    <link rel="stylesheet" href="style.css"/>
    <style>
        body {
            text-align: center;
            background-image: url("https://joshthinh.github.io/Asian-United-Frontend/images/background.png"); /* Add the path to your background image */
            background-size: cover;
        }
        .login-container {
            width: 300px;
            margin: 0 auto;
            padding: 20px;
            border: 1px solid #cccccc00;
            background-color: rgba(255, 255, 255, 0); /* Adjust the alpha value (0.0 to 1.0) for transparency */
            margin-top: 50px;
        }
        .login-container label {
            color: white; /* Set the text color to white */
        }
        .login-container input[type="text"],
        .login-container input[type="password"] {
            color: black; /* Set the text color to black */
        }
        .login-container h1 {
            color: #ffffff; /* Set the text color of "Login" to a different color */
        }
        .login-guest-button {
            text-align: center;
            position: absolute;
            bottom: 50px;
            right: 0;
            margin: 20px;
        }
        .dont-have-account-button {
            text-align: center;
            position: absolute;
            bottom: 10px; /* Adjust the vertical position */
            right: 0;
            margin: 20px;
        }
    </style>
</head>
<body>
    <!-- Content for Login Page -->
    <div class="login-container">
        <h1>Login</h1>
        <!--<form method="post" action="process_login.php"> -->
            <form id="loginForm">
                <label for="username">Username:</label>
                <input type="text" id="username" name="username" required><br>
        
                <label for="password">Password:</label>
                <input type="password" id="password" name="password" required><br>
        
                <button type="button" onclick="authenticateUser()">Login</button>
            </form>
        
            <div id="output"></div>
        
            <script src="https://joshthinh.github.io/Asian-United-Frontend/passscript.js"></script>
        </form>
    </div>
    <button class="login-guest-button"><a href="https://joshthinh.github.io/Asian-United-Frontend/game.html">Login as Guest</a></button>
    <button class="dont-have-account-button"><a href="https://joshthinh.github.io/Asian-United-Frontend/signup.html">Don't Have an Account?</a></button>
    <!-- Include any footer content if needed -->
</body>
</html>
<script>
</script>

# %%
<!DOCTYPE html>
<html>
<head>
    <title>Asian.inc - Sign Up</title>
    <link rel="stylesheet" href="style.css"/>
    <style>
        body {
            text-align: center;
            background-image: url("https://joshthinh.github.io/Asian-United-Frontend/images/background.png"); /* Add the path to your background image */
            background-size: cover;
        }
        .signup-container {
            width: 300px;
            margin: 0 auto;
            padding: 20px;
            border: 1px solid #cccccc00;
            background-color: rgba(255, 255, 255, 0); /* Adjust the alpha value (0.0 to 1.0) for transparency */
            margin-top: 50px;
        }
        .signup-container label {
            color: white; /* Set the text color to white */
        }
        .signup-container input[type="text"],
        .signup-container input[type="password"] {
            color: black; /* Set the text color to black */
        }
        .signup-container h1 {
            color: #ffffff; /* Set the text color of "Sign Up" to a different color */
        }
        .login-button {
            text-align: center;
            position: absolute;
            bottom: 10px;
            right: 0;
            margin: 20px;
        }
        .login-guest-button {
            text-align: center;
            position: absolute;
            bottom: 50px; /* Adjust the vertical position */
            right: 0;
            margin: 20px;
        }
    </style>
</head>
<body>
    <!-- Content for Sign-up Page -->
    <div class="signup-container">
        <h1>Sign Up</h1>
        <form>
            <label for="username">Username:</label>
            <input type="text" name="username" id="signupuser" required><br>
            <label for="password">Password:</label>
            <input type="password" name="password" id="signuppass" required><br>  
            <script src="https://joshthinh.github.io/Asian-United-Frontend/passscript.js"></script>
            <!-- Add more form fields as needed -->
            <button type = "button" text="Sign Up" onclick = "registerUser()">Sign Up</button>
        </form>
        <div id = "output"></div>
    </div>
    <button class="login-guest-button"><a href="https://joshthinh.github.io/Asian-United-Frontend/game.html">Login as Guest</a></button>
    <button class="login-button"><a href="https://joshthinh.github.io/Asian-United-Frontend/login.html">Already Have an Account?</a></button>
    <!-- Include any footer content if needed -->
</body>
</html>
